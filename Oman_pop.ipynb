# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/Oman_pop.csv')
data
# Out:
#              city      lon        lat       pop
# 0          Muscat  23.5880    58.3829  200000.0
# 1           Sohar  24.3501    56.7133   80000.0
# 2         Salalah  17.0194    54.1108  100000.0
# 3            Ibri  23.2359    56.4944   40000.0
# 4           Nizwa  22.9171    57.5363   80000.0
# 5           Madha  18.0340    75.5161   10000.0
# 6         Buraimi  24.2815    55.8246   15000.0
# 7  Haiman 19.9535  56.2873  7000.0000       NaN
# 8         Masirah  20.3173    58.6916    2000.0
# 9           Sadah  16.9509    43.7478    1000.0

# %%
sns.barplot(x='city', y='pop', data=data, palette= sns.color_palette('Set1', 10))
# Out:
# <Axes: xlabel='city', ylabel='pop'>

# %%
sns
# Out:
# /tmp/ipykernel_22015/1194839762.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
# <Axes: >
